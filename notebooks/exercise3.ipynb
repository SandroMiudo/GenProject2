# %%
import sys
import os

sys.path.append(os.path.abspath("../"))

import json

import torch
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
from torch import nn
from torch.utils.data import DataLoader

from data_utils import save_model, get_dataset_path, visualize_batch
from data_utils.BrainDataset import BrainDataset
from data_utils.BrainSampler import BrainSampler

from gan import (
    Generator,
    Critic,
    base
)

# %%
training_params = {
    "batch_size" : 64,
    "batch_gpu" : 64,
    "train_time" : int(1*10e3),
    "tile_size" : 64,
    "training_brains" : [(1818, 759, "left"), (1818,820, "right"), (1818, 830, "right")],
    "map_type" : "fom",
    "resolution": "00",
    "lr_disc" : 1e-4,
    "lr_gan" : 1e-4,
    "wd_disc" : 0,
    "wd_gan" : 0,
    "latent_dim" : 32,
    "n_critic": 1,
    "l_factor": 1,
    "grad_penalty": 10,
    "beta_1" : 0,
    "beta_2" : 0.9
}
assert training_params["batch_size"] % training_params["batch_gpu"] == 0
torch.random.manual_seed(0)
data = BrainDataset(training_params["training_brains"], training_params["map_type"], training_params["resolution"])
sampler = BrainSampler(data, tile_size=training_params["tile_size"], map_type=training_params["map_type"])
loader = DataLoader(data, sampler=sampler, batch_size=training_params["batch_size"])

model = Generator(3 if training_params["map_type"] == "fom" else 1, training_params["latent_dim"])
discriminator = Critic(3 if training_params["map_type"] == "fom" else 1)
optimizer_gan = torch.optim.Adam(model.parameters(), lr=training_params["lr_gan"], weight_decay=training_params["wd_gan"], 
                                 betas=(training_params["beta_1"], training_params["beta_2"]))
optimizer_disc = torch.optim.Adam(discriminator.parameters(), lr=training_params["lr_disc"], weight_decay=training_params["wd_disc"],
                                  betas=(training_params["beta_1"], training_params["beta_2"]))
device = torch.device("cuda")

# %%
def training_loop():
    losses_disc = []
    losses_gan = []
    model.train()
    model.to(device)
    discriminator.train()
    discriminator.to(device)
    total_batch_count = training_params["train_time"] // training_params["batch_size"]
    data_iter = iter(loader)
    pbar = tqdm(range(total_batch_count))
    eps = 1e-6
    for _ in pbar:
        batch_loss_gan = 0
        # Optimize Discriminator
        for i in range(training_params["n_critic"]):
            batch_loss_disc = 0
            optimizer_disc.zero_grad()
            for _ in range(training_params["batch_size"] // training_params["batch_gpu"]):
                x = next(data_iter)[0].to(device)
                z = torch.randn(training_params["batch_gpu"], training_params["latent_dim"], 1, 1, device=device)
                x_gen = model(z)
                cr_real = discriminator(x)
                cr_fake = discriminator(x_gen)
                batch_loss_disc += base.critic_loss(x, x_gen, discriminator, cr_real=cr_real, cr_fake=cr_fake, 
                                  _lambda=training_params["grad_penalty"], _lipschitz_factor=training_params["l_factor"])
                
                batch_loss_disc.backward()

                optimizer_disc.step()

        # Optimize Generator
        optimizer_gan.zero_grad()
        for _ in range(training_params["batch_size"] // training_params["batch_gpu"]):
            z = torch.randn(training_params["batch_gpu"], training_params["latent_dim"], 1, 1, device=device)
            batch_loss_gan += base.generator_loss(z, model, discriminator)

            batch_loss_gan.backward()

            optimizer_gan.step()

        pbar.set_description(f"Critic loss: {batch_loss_disc:.4f} Generator loss: {batch_loss_gan:.4f}")
        losses_disc.append(batch_loss_disc.item())
        losses_gan.append(batch_loss_gan.item())
    save_model(model,discriminator, training_params)
    return losses_disc, losses_gan

# %%
losses_disc, losses_gan = training_loop()
plt.plot(losses_disc)
plt.plot(losses_gan)
# Out:
#   0%|          | 0/156 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 losses_disc, losses_gan = training_loop()
#       2 plt.plot(losses_disc)
#       3 plt.plot(losses_gan)
#
# Cell In[3], line 27, in training_loop()
#      23         cr_fake = discriminator(x_gen)
#      24         batch_loss_disc += base.critic_loss(x, x_gen, discriminator, cr_real=cr_real, cr_fake=cr_fake,
#      25                           _lambda=training_params["grad_penalty"], _lipschitz_factor=training_params["l_factor"])
# ---> 27         batch_loss_disc.backward()
#      29         optimizer_disc.step()
#      31 # Optimize Generator
#
# File ~/.conda/envs/var_auto_encoder/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~/.conda/envs/var_auto_encoder/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/.conda/envs/var_auto_encoder/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
model_name = "8006146278150"
model_dict = torch.load(os.path.join(get_dataset_path(), f"../models", f"{model_name}/model.pt"), weights_only=True)
options = json.load(open(os.path.join(get_dataset_path(), "../models", f"{model_name}/options.json"), "r"))
model = Generator(3, options["latent_dim"])
model.load_state_dict(model_dict)
model = model.eval()
model = model.to(device)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
torch.random.manual_seed(0)
samples = model.sample(30)
visualize_batch(samples, "fom")
